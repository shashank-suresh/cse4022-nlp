# %% [markdown]
# # Task 1

# %%
def gender_features(word):
    """Extracts and returns the last character of the word"""
    return {'last_letter': word[-1]}

# %%
gender_features("Shashank")
# Out:
# {'last_letter': 'k'}

# %%
import nltk
from nltk.corpus import names
import random

# %%
# Assign the label 'male' for each name in the 'male.txt' word file and do the same with the label 'female'
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Brendan', 'male'),
#  ('Daria', 'female'),
#  ('Myranda', 'female'),
#  ('Paten', 'male'),
#  ('Rollins', 'male'),
#  ('Kylila', 'female'),
#  ('Blare', 'male'),
#  ('Diane', 'female'),
#  ('Morty', 'male'),
#  ('Jolene', 'female'),
#  ('Lenore', 'female'),
#  ('Bernetta', 'female'),
#  ('Valentina', 'female'),
#  ('Pauli', 'female'),
#  ('Josephus', 'male'),
#  ('Iggie', 'male'),
#  ('Johnny', 'male'),
#  ('Noach', 'male'),
#  ('Tildy', 'female'),
#  ('Suzy', 'female'),
#  ('Fenelia', 'female'),
#  ('Corina', 'female'),
#  ('Jules', 'male'),
#  ('Pooh', 'male'),
#  ('Hastings', 'male'),
#  ('Dwight', 'male'),
#  ('Jeanette', 'female'),
#  ('Weston', 'male'),
#  ('Elyse', 'female'),
#  ('Merrily', 'female'),
#  ('Sig', 'male'),
#  ('Kristin', 'female'),
#  ('Silvie', 'female'),
#  ('Annemarie', 'female'),
#  ('Etienne', 'male'),
#  ('Aleta', 'female'),
#  ('Arlena', 'female'),
#  ('Allan', 'male'),
#  ('Ivor', 'male'),
#  ('Ardeen', 'female'),
#  ('Angil', 'female'),
# ...

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
# ...

# %%
len(featuresets)
# Out:
# 7944

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Shashank'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.76

# %% [markdown]
# # Task 2 - Tweet Tokenizer

# %%
import nltk
from nltk.tokenize import TweetTokenizer

# %%
text = "The Party was sooooo fun :D #superfun"
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'Party', 'was', 'sooooo', 'fun', ':D', '#superfun']

# %% [markdown]
# # Task 3 - Explore COCA

# %% [markdown]
# ## Task 3.1 - Find the frequency count of a word

# %% [markdown]
# ![Task 3.1 Screenshot](task3-1.png)

# %% [markdown]
# ## Task 3.2 - Chart - word - frequency; section; sub-section; year

# %% [markdown]
# Chart generated for the words "rosa parks"

# %% [markdown]
# ![Task 3.2 Screenshot](task3-2.png)

# %% [markdown]
# ## Task 3.3 - Collocate - Display three collocations on the left and right each of the word

# %% [markdown]
# General summary

# %% [markdown]
# ![Task 3.3 General Summary Screenshot](task3-3-1.png)

# %% [markdown]
# Most common collocates

# %% [markdown]
# ![Task 3.3 Most Common Collocates Screenshot](task3-3-2.png)

# %% [markdown]
# Clusters (displays 3 collocations on the left and right side each of the word)

# %% [markdown]
# ![Task 3.3 Cluster Screenshot](task3-3-3.png)
